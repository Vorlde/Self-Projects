# %% [markdown]
# ## XGBoost Strategy: Himanshu Kumar

# %%
import pandas as pd
import numpy as np
import time
import json
import talib as ta
import warnings
import pyfolio as pf
import numpy as np
from sklearn.model_selection import KFold
import xgboost as xgb

from imblearn.over_sampling import RandomOverSampler
from imblearn.under_sampling import RandomUnderSampler
over_sampler = RandomOverSampler()
warnings.filterwarnings("ignore")

from matplotlib import pyplot as plt
import plotly.graph_objs as go

import ipywidgets as widgets
from ipywidgets import interact
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
# Out:
# C:\Users\hksci\anaconda3\lib\site-packages\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; mutltipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; mutltipliers will not be applied' +

# %% [markdown]
# ### Df and Features

# %%
def add_pivots(df_daily):
    df_daily["Pivot"] = df_daily[[ 'High', 'Low', 'Close']].mean(axis =1).round(2).shift(1)
    df_daily["Bcpr"]  = df_daily[[ 'High', 'Low'        ]].mean(axis =1).round(2).shift(1)
    df_daily["Tcpr"]  = 2 * df_daily["Pivot"] - df_daily["Bcpr"] 
    df_daily["H3"]    = (df_daily["Close"] + (df_daily["High"] - df_daily["Low"])* 1.1/4).round(2).shift(1)
    df_daily["H4"]    = (df_daily["Close"] + (df_daily["High"] - df_daily["Low"])* 1.1/2).round(2).shift(1)
    df_daily["L3"]    = (df_daily["Close"] - (df_daily["High"] - df_daily["Low"])* 1.1/4).round(2).shift(1)
    df_daily["L4"]    = (df_daily["Close"] - (df_daily["High"] - df_daily["Low"])* 1.1/2).round(2).shift(1)

    df_daily["width"] = df_daily["H4"] - df_daily["H3"] 
    df_daily["H3_in_CPR"] =  ((df_daily['H3'] < df_daily['Pivot'])).astype(int)
    df_daily["L3_in_CPR"] =  ((df_daily['L3'] > df_daily['Pivot'])).astype(int)
    df_daily["BC>TC"] = (df_daily["Bcpr"] > df_daily["Tcpr"] ).astype(int)
    
    return df_daily

# %%
def pre_process():
    df = pd.read_csv("BNF_1min.csv")

    # select columns to round
    cols_to_round = ['O', 'H', 'L', 'C', 'VWAP', 'AdjFac', 'CaxFac',"rolling_vol"]

    # round columns to 2 decimal places
    df[cols_to_round] = df[cols_to_round].round(2)

    # rename columns
    df = df.rename(columns={'O': 'Open', 'H': 'High', 'L': 'Low', 'C': 'Close', "V" : "Volume"})

    df['timestamp'] = pd.to_datetime(df['timestamp'])
    df = df.set_index('timestamp')

    # Resample to daily OHLC data
    ohlc_dict = {'Open': 'first', 'High': 'max', 'Low': 'min', 'Close': 'last','Volume': 'sum', 'VWAP': 'mean'}
    df_daily = df.resample('D').agg(ohlc_dict)
    df_daily.dropna(inplace = True)
    
    #add pivot_levels
    df_daily = add_pivots(df_daily)
    
    # merge daily, Join `df_daily` and `df`
    df["timestamp"] =  df.index
    df['Date'] = df.index.date
    df['Time'] = df['timestamp'].dt.strftime('%H:%M:%S')
    df_daily['Date'] = df_daily.index.date

    columns_to_merge = ['Date','Pivot','Bcpr', 'Tcpr', 'H3', 'H4', 'L3', 'L4','width', 'H3_in_CPR', 'L3_in_CPR','BC>TC']
    merged_df = pd.merge(df, df_daily[columns_to_merge], on= 'Date')
    merged_df.drop(columns = ["Date"], inplace = True)
    merged_df['timestamp'] = pd.to_datetime(merged_df['timestamp'])
    merged_df = merged_df.set_index('timestamp')
    
    #dropna before buy_sell
    merged_df.dropna(inplace = True)
    
    return merged_df

# %%
def add_indicators(df):
    df['avg_high_and_low']=(df['High']+df['Low'])/2
    df['ADX']=ta.ADX(df['High'],df['Low'],df['Close'],timeperiod=50)
    df['RSI']=ta.RSI(df['Close'],timeperiod=50)
    df['AO']=(ta.SMA(df['avg_high_and_low'], timeperiod=5)-ta.SMA(df['avg_high_and_low'], timeperiod=34))
    df['ATR']=ta.ATR(df['High'],df['Low'],df['Close'],timeperiod=21)

    body = abs(df["High"]- df["Low"])
    df["ATR_Condn"] = body > df['ATR']
    
    df["AO_Cond"] = df["AO"]>0
    df["VWAP_Cond"] = df["VWAP"] < df["Close"]
    
    # Add Awesome Oscillator
    ao = df["AO"]
    ao1=df['AO'].shift(1)
    ao2=df['AO'].shift(2)
    ao3=df['AO'].shift(3)
    ao4=df['AO'].shift(4)

    #at current c&le
    df["AO_DU"] = (ao<ao1) & (ao1<ao2) & (ao2>ao3) & (ao3>ao4)
    df["AO_U"]  = (ao>ao1) & (ao1>ao2) & (ao2<ao3) & (ao3<ao4) 
    
    # Ao turns +ve or -ve
    df['positive_to_negative'] = (df['AO'] > 0) & (df['AO'].shift(1) > 0) & (df['AO'] < df['AO'].shift(1)) 
    df['negative_to_positive'] = (df['AO'] < 0) & (df['AO'].shift(1) < 0) & (df['AO'] > df['AO'].shift(1))
    
    df["SMA_750"] =  ta.SMA(df['Close'],timeperiod= 750).round(2)
    df["P>750SMA"] = (df["Close"] > df["SMA_750"]).astype(int)
    
    df["SMA_300"] = (ta.SMA(df['Close'],timeperiod= 300).round(2))  
    df["P>300SMA"] = (df["Close"] > df["SMA_300"]).astype(int)
    
    df.dropna(inplace = True)
    
    return df

# %%
def add_signals(df):
    
    df["buy"]  =  df["AO_DU"] & (df["Close"] > df["L4"]) & df["P>750SMA"] 
    df["sell"]   = df["AO_U"] & (df["Close"] < df["H3"]) 

    # calculate the crossover signal, for agressive trailing
    df["SMA_cross_d"] = (df["Close"] > df["SMA_300"]) & (df["Close"].shift(1) < df["SMA_300"].shift(1))
    df["SMA_cross_u"] = (df["Close"] < df["SMA_300"]) & (df["Close"].shift(1) > df["SMA_300"].shift(1))

    df["exit_buy_profit"] =  df["SMA_cross_d"] & df["P>750SMA"] &  (df["Close"] > df["Tcpr"])
    df["exit_sell_profit"] = df["SMA_cross_u"] & (df["P>750SMA"] == False) & (df["Close"] < df["Bcpr"])

    n1 = 3
    df["Buy_Target"] = df["Close"] + (n1 * df["ATR"])

    n2 = 3
    df["Sell_Target"] = df["Close"] - (n2 * df["ATR"])

    m1 = 3
    df["Buy_SL"] = df["Close"] - (m1 * df["ATR"])

    m2 = 3
    df["Sell_SL"] = df["Close"] + (m2 * df["ATR"])
   
    
#     df["buy"]    = df["AO_U"] & df["P>750SMA"] & (df["Close"] > df["L4"])
#     df["sell"]   = df["AO_DU"] & (df["P>750SMA"]==False) & (df["Close"] < df["H4"]) 
    
    return df

# %%
def backtest(df):
    
    pos = 0
    target = 0
    sl = 0
    enter_price = 0
    store_i = 1
    
    df["Exit_Signal"] = None
    df["Sell_Signal"] = None
    df["Pos"] = 0
    df["Signal_name"]=None
    df["returns"] = 0

    
    for i in range(1, len(df)-1):

        if pos == 0: 

            if df["buy"].iloc[i]:
                store_i = i
                pos = 1
                df["Pos"].iloc[i] = 1

                enter_price = df["Open"].iloc[i+1]
                df["Signal_name"].iloc[i]= 'Supertrend Buy'

                target = df["Buy_Target"].iloc[i] 
                sl     = df["Buy_SL"].iloc[i]

            elif df["sell"].iloc[i] : 
                store_i = i

                df["Pos"].iloc[i] = -1
                pos = -1

                enter_price = df["Open"].iloc[i+1]
                df['Signal_name'].iloc[i]='Supertrend Sell'

                target =  df["Sell_Target"].iloc[i] 
                sl     =  df["Sell_SL"].iloc[i]


        elif pos == 1:

            if ((df['Close'].iloc[i] < sl ) | df['positive_to_negative'].iloc[i] | (df['Close'].iloc[i] > target )):
                df["Pos"].iloc[i] = 0
                pos = 0
                df["Exit_Signal"].iloc[i] = 1

                df["returns"].iloc[store_i] =  ((df['Open'].iloc[i+1] - enter_price) /enter_price)

                if (df['Close'].iloc[i] < sl ):
                    df['Signal_name'].iloc[i]='Exit Buy SL Hit'

                elif (df['Close'].iloc[i] > target ):
                    df['Signal_name'].iloc[i]='Exit Buy Target Hit'

                else :
                    df['Signal_name'].iloc[i]='positive_to_negative'

            elif df["exit_buy_profit"].iloc[i] :

                df["Pos"].iloc[i] = 0
                pos = 0            
                df["returns"].iloc[store_i] = ((df['Open'].iloc[i+1] - enter_price) /enter_price)
                df['Signal_name'].iloc[i] = 'exit_buy_profit'

        elif pos == -1:

            if ((df['Close'].iloc[i] > sl ) |  df['negative_to_positive'].iloc[i] | (df['Close'].iloc[i] < target ) ):
                df["Pos"].iloc[i] = 0
                pos = 0
                df["Exit_Signal"].iloc[i] = 1

                df["returns"].iloc[store_i] = ((enter_price - df['Open'].iloc[i+1] ) /enter_price)
                if (df['Close'].iloc[i] > sl ):
                    df['Signal_name'].iloc[i]='Exit Sell SL Hit'

                elif (df['Close'].iloc[i] < target ):
                    df['Signal_name'].iloc[i]='Exit Sell Target Hit'

                else :
                    df['Signal_name'].iloc[i]='negative_to_positive'

            elif df["exit_sell_profit"].iloc[i] :

                df["Pos"].iloc[i] = 0
                pos = 0

                df["returns"].iloc[store_i] =((enter_price - df['Open'].iloc[i+1]) /enter_price)
                df['Signal_name'].iloc[i] = 'exit_sell_profit'
                
    return df

# %%
def post_trade_stats(df):
    print(df["Pos"].value_counts())
    pf.display(pf.create_simple_tear_sheet(np.log(1+df[df["Pos"] != 0]['returns'])))
    df["Profitable"] = (df["returns"] > 0)
    print(f"Profitable trades: {df['Profitable'].sum()}")
    
    return df

# %% [markdown]
# ## Model Development

# %%
def XGBoost_dataprep(df,train_set=0.8):
    
    df_train = df[df["Pos"] != 0]
    
    Features= ['ADX', 'RSI', 'ATR',"VWAP_Cond","width"]
    X = df_train[Features]
    y = df_train["Profitable"]
       
    cutoff = int(len(df_train)*train_set)
    X_train, y_train = X[:cutoff], y[:cutoff]
    X_test, y_test   = X[cutoff:], y[cutoff:]
    
    X_train_over, y_train_over = over_sampler.fit_resample(X,y)


    # Plot class balance
    df_train["Profitable"].value_counts().plot(kind="bar",
    xlabel = "Profitable", ylabel = "frequency", title = "Class Balance"
    );
    
    return X_train_over,y_train_over,X_test,y_test,Features

# %%
def train_model(X,y,n_splits=5):
    
    X = X.to_numpy()
    y = y.to_numpy()
    # Create an XGBoost classifier model
    model = xgb.XGBClassifier(learning_rate=0.01,
                              max_depth=6,
                              n_estimators=5000)

    # Create a cross-validation object
    kf = KFold(n_splits)

    # Initialize lists to store the scores for each fold
    train_scores = []
    test_scores = []

    # Loop through each fold
    for train_idx, test_idx in kf.split(X):
        
        # Split the data into training and test sets for the current fold
        X_train, y_train = X[train_idx], y[train_idx]
        X_test, y_test = X[test_idx], y[test_idx]

        eval_set = [(X_test, y_test)]

        # Train the model on the training data
        model.fit(X_train, y_train, eval_set=eval_set, early_stopping_rounds=15)

        # Evaluate the model on the training data
        train_score = model.score(X_train, y_train)
        train_scores.append(train_score)

        # Evaluate the model on the test data
        test_score = model.score(X_test, y_test)
        test_scores.append(test_score)

    # Compute and print the mean and standard deviation of the scores
    print(f"Train Scores: {np.mean(train_scores):.3f} +/- {np.std(train_scores):.3f}")
    print(f"Test Scores: {np.mean(test_scores):.3f} +/- {np.std(test_scores):.3f}")
    
   
    return model

# %%
def model_trade(df,model,features):
    
    def make_cnf_matrix(threshold):
        test_df = df[df["Pos"] != 0]
        X = test_df[features]

        y_pred_proba = model.predict_proba(X)[:,-1]
        y_pred = y_pred_proba > threshold


        test_df["y_pred"] = y_pred
        test_df["returns_model"] = test_df["returns"] * (test_df["y_pred"])

        pf.display(pf.create_simple_tear_sheet(np.log(1+test_df[test_df["Pos"] != 0]['returns_model'])))


    thresh_widget = widgets.FloatSlider(min=0,max=1,value=0.5,step=0.05)

    interact(make_cnf_matrix, threshold=thresh_widget);
    
    return df

# %%
data = pre_process()
data = add_indicators(data)
data = add_signals(data)
data = backtest(data[:90000])
data = post_trade_stats(data)
# Out:
#  0    84975
# -1     2881
#  1     2144
# Name: Pos, dtype: int64
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-03-10</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2022-03-07</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>239</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>0.6%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>12.3%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>2.7%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.06</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.61</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-9.1%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-1.79</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>72.39</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.3%</td>
#     </tr>
#   </tbody>
# </table>
# None
# Profitable trades: 2544

# %%
returns = data[data["Pos"] != 0]["returns"]

# Create a histogram of the returns
plt.hist(returns, bins=20)
plt.xlabel("Returns")
plt.ylabel("Frequency")
plt.title("Distribution of Returns")
plt.show()

# %%
X,y,X_test,y_test,features = XGBoost_dataprep(data)

# %%
model = train_model(X,y)
# Out:
# [0]	validation_0-logloss:0.69314
# [1]	validation_0-logloss:0.69311
# [2]	validation_0-logloss:0.69311
# [3]	validation_0-logloss:0.69311
# [4]	validation_0-logloss:0.69311
# [5]	validation_0-logloss:0.69308
# [6]	validation_0-logloss:0.69305
# [7]	validation_0-logloss:0.69307
# [8]	validation_0-logloss:0.69310
# [9]	validation_0-logloss:0.69308
# [10]	validation_0-logloss:0.69310
# [11]	validation_0-logloss:0.69311
# [12]	validation_0-logloss:0.69316
# [13]	validation_0-logloss:0.69316
# [14]	validation_0-logloss:0.69321
# [15]	validation_0-logloss:0.69322
# [16]	validation_0-logloss:0.69327
# [17]	validation_0-logloss:0.69328
# [18]	validation_0-logloss:0.69330
# [19]	validation_0-logloss:0.69333
# [20]	validation_0-logloss:0.69342
# [21]	validation_0-logloss:0.69342
# [0]	validation_0-logloss:0.69301
# [1]	validation_0-logloss:0.69288
# [2]	validation_0-logloss:0.69276
# [3]	validation_0-logloss:0.69264
# [4]	validation_0-logloss:0.69251
# [5]	validation_0-logloss:0.69234
# [6]	validation_0-logloss:0.69230
# [7]	validation_0-logloss:0.69226
# [8]	validation_0-logloss:0.69212
# [9]	validation_0-logloss:0.69211
# [10]	validation_0-logloss:0.69216
# [11]	validation_0-logloss:0.69210
# [12]	validation_0-logloss:0.69211
# [13]	validation_0-logloss:0.69212
# [14]	validation_0-logloss:0.69211
# [15]	validation_0-logloss:0.69194
# [16]	validation_0-logloss:0.69193
# [17]	validation_0-logloss:0.69193
# [18]	validation_0-logloss:0.69186
# [19]	validation_0-logloss:0.69191
# [20]	validation_0-logloss:0.69186
# [21]	validation_0-logloss:0.69186
# [22]	validation_0-logloss:0.69176
# [23]	validation_0-logloss:0.69167
# [24]	validation_0-logloss:0.69158
# [25]	validation_0-logloss:0.69150
# [26]	validation_0-logloss:0.69152
# [27]	validation_0-logloss:0.69144
# [28]	validation_0-logloss:0.69136
# [29]	validation_0-logloss:0.69131
# [30]	validation_0-logloss:0.69123
# [31]	validation_0-logloss:0.69121
# [32]	validation_0-logloss:0.69122
# [33]	validation_0-logloss:0.69119
# [34]	validation_0-logloss:0.69119
# [35]	validation_0-logloss:0.69121
# [36]	validation_0-logloss:0.69120
# [37]	validation_0-logloss:0.69119
# [38]	validation_0-logloss:0.69122
# [39]	validation_0-logloss:0.69122
# [40]	validation_0-logloss:0.69126
# [41]	validation_0-logloss:0.69127
# [42]	validation_0-logloss:0.69129
# [43]	validation_0-logloss:0.69127
# [44]	validation_0-logloss:0.69128
# [45]	validation_0-logloss:0.69129
# [46]	validation_0-logloss:0.69133
# [47]	validation_0-logloss:0.69135
# [48]	validation_0-logloss:0.69135
# [49]	validation_0-logloss:0.69139
# [50]	validation_0-logloss:0.69139
# [51]	validation_0-logloss:0.69139
# [0]	validation_0-logloss:0.69308
# [1]	validation_0-logloss:0.69300
# [2]	validation_0-logloss:0.69295
# [3]	validation_0-logloss:0.69288
# [4]	validation_0-logloss:0.69281
# [5]	validation_0-logloss:0.69270
# [6]	validation_0-logloss:0.69261
# [7]	validation_0-logloss:0.69255
# [8]	validation_0-logloss:0.69251
# [9]	validation_0-logloss:0.69247
# [10]	validation_0-logloss:0.69244
# [11]	validation_0-logloss:0.69238
# [12]	validation_0-logloss:0.69232
# [13]	validation_0-logloss:0.69227
# [14]	validation_0-logloss:0.69224
# [15]	validation_0-logloss:0.69220
# [16]	validation_0-logloss:0.69215
# [17]	validation_0-logloss:0.69212
# [18]	validation_0-logloss:0.69208
# [19]	validation_0-logloss:0.69204
# [20]	validation_0-logloss:0.69198
# [21]	validation_0-logloss:0.69196
# [22]	validation_0-logloss:0.69194
# [23]	validation_0-logloss:0.69195
# [24]	validation_0-logloss:0.69187
# [25]	validation_0-logloss:0.69187
# [26]	validation_0-logloss:0.69188
# [27]	validation_0-logloss:0.69179
# [28]	validation_0-logloss:0.69171
# [29]	validation_0-logloss:0.69163
# [30]	validation_0-logloss:0.69155
# [31]	validation_0-logloss:0.69147
# [32]	validation_0-logloss:0.69140
# [33]	validation_0-logloss:0.69134
# [34]	validation_0-logloss:0.69128
# [35]	validation_0-logloss:0.69123
# [36]	validation_0-logloss:0.69121
# [37]	validation_0-logloss:0.69121
# [38]	validation_0-logloss:0.69119
# [39]	validation_0-logloss:0.69119
# [40]	validation_0-logloss:0.69116
# [41]	validation_0-logloss:0.69111
# [42]	validation_0-logloss:0.69107
# [43]	validation_0-logloss:0.69108
# [44]	validation_0-logloss:0.69103
# [45]	validation_0-logloss:0.69097
# [46]	validation_0-logloss:0.69092
# [47]	validation_0-logloss:0.69093
# [48]	validation_0-logloss:0.69089
# [49]	validation_0-logloss:0.69084
# [50]	validation_0-logloss:0.69080
# [51]	validation_0-logloss:0.69072
# [52]	validation_0-logloss:0.69067
# [53]	validation_0-logloss:0.69064
# [54]	validation_0-logloss:0.69057
# [55]	validation_0-logloss:0.69053
# [56]	validation_0-logloss:0.69051
# [57]	validation_0-logloss:0.69050
# [58]	validation_0-logloss:0.69047
# [59]	validation_0-logloss:0.69043
# [60]	validation_0-logloss:0.69036
# [61]	validation_0-logloss:0.69033
# [62]	validation_0-logloss:0.69035
# [63]	validation_0-logloss:0.69031
# [64]	validation_0-logloss:0.69031
# [65]	validation_0-logloss:0.69030
# [66]	validation_0-logloss:0.69033
# [67]	validation_0-logloss:0.69033
# [68]	validation_0-logloss:0.69033
# [69]	validation_0-logloss:0.69032
# [70]	validation_0-logloss:0.69032
# [71]	validation_0-logloss:0.69032
# [72]	validation_0-logloss:0.69032
# [73]	validation_0-logloss:0.69031
# [74]	validation_0-logloss:0.69032
# [75]	validation_0-logloss:0.69033
# [76]	validation_0-logloss:0.69028
# [77]	validation_0-logloss:0.69029
# [78]	validation_0-logloss:0.69021
# [79]	validation_0-logloss:0.69020
# [80]	validation_0-logloss:0.69022
# [81]	validation_0-logloss:0.69019
# [82]	validation_0-logloss:0.69020
# [83]	validation_0-logloss:0.69018
# [84]	validation_0-logloss:0.69018
# [85]	validation_0-logloss:0.69018
# [86]	validation_0-logloss:0.69014
# [87]	validation_0-logloss:0.69019
# [88]	validation_0-logloss:0.69018
# [89]	validation_0-logloss:0.69018
# [90]	validation_0-logloss:0.69012
# [91]	validation_0-logloss:0.69012
# [92]	validation_0-logloss:0.69012
# [93]	validation_0-logloss:0.69017
# [94]	validation_0-logloss:0.69019
# [95]	validation_0-logloss:0.69017
# [96]	validation_0-logloss:0.69018
# [97]	validation_0-logloss:0.69020
# [98]	validation_0-logloss:0.69015
# [99]	validation_0-logloss:0.69018
# [100]	validation_0-logloss:0.69017
# [101]	validation_0-logloss:0.69019
# [102]	validation_0-logloss:0.69019
# [103]	validation_0-logloss:0.69020
# [104]	validation_0-logloss:0.69017
# [105]	validation_0-logloss:0.69014
# [106]	validation_0-logloss:0.69018
# [107]	validation_0-logloss:0.69017
# [0]	validation_0-logloss:0.69306
# [1]	validation_0-logloss:0.69298
# [2]	validation_0-logloss:0.69290
# [3]	validation_0-logloss:0.69287
# [4]	validation_0-logloss:0.69279
# [5]	validation_0-logloss:0.69277
# [6]	validation_0-logloss:0.69273
# [7]	validation_0-logloss:0.69267
# [8]	validation_0-logloss:0.69265
# [9]	validation_0-logloss:0.69257
# [10]	validation_0-logloss:0.69255
# [11]	validation_0-logloss:0.69248
# [12]	validation_0-logloss:0.69245
# [13]	validation_0-logloss:0.69241
# [14]	validation_0-logloss:0.69237
# [15]	validation_0-logloss:0.69236
# [16]	validation_0-logloss:0.69233
# [17]	validation_0-logloss:0.69230
# [18]	validation_0-logloss:0.69231
# [19]	validation_0-logloss:0.69226
# [20]	validation_0-logloss:0.69221
# [21]	validation_0-logloss:0.69218
# [22]	validation_0-logloss:0.69211
# [23]	validation_0-logloss:0.69209
# [24]	validation_0-logloss:0.69205
# [25]	validation_0-logloss:0.69201
# [26]	validation_0-logloss:0.69197
# [27]	validation_0-logloss:0.69194
# [28]	validation_0-logloss:0.69189
# [29]	validation_0-logloss:0.69185
# [30]	validation_0-logloss:0.69182
# [31]	validation_0-logloss:0.69176
# [32]	validation_0-logloss:0.69174
# [33]	validation_0-logloss:0.69169
# [34]	validation_0-logloss:0.69166
# [35]	validation_0-logloss:0.69164
# [36]	validation_0-logloss:0.69160
# [37]	validation_0-logloss:0.69156
# [38]	validation_0-logloss:0.69155
# [39]	validation_0-logloss:0.69153
# [40]	validation_0-logloss:0.69149
# [41]	validation_0-logloss:0.69147
# [42]	validation_0-logloss:0.69145
# [43]	validation_0-logloss:0.69145
# [44]	validation_0-logloss:0.69144
# [45]	validation_0-logloss:0.69142
# [46]	validation_0-logloss:0.69138
# [47]	validation_0-logloss:0.69136
# [48]	validation_0-logloss:0.69136
# [49]	validation_0-logloss:0.69134
# [50]	validation_0-logloss:0.69133
# [51]	validation_0-logloss:0.69128
# [52]	validation_0-logloss:0.69126
# [53]	validation_0-logloss:0.69125
# [54]	validation_0-logloss:0.69124
# [55]	validation_0-logloss:0.69128
# [56]	validation_0-logloss:0.69125
# [57]	validation_0-logloss:0.69126
# [58]	validation_0-logloss:0.69125
# [59]	validation_0-logloss:0.69127
# [60]	validation_0-logloss:0.69124
# [61]	validation_0-logloss:0.69125
# [62]	validation_0-logloss:0.69126
# [63]	validation_0-logloss:0.69125
# [64]	validation_0-logloss:0.69125
# [65]	validation_0-logloss:0.69130
# [66]	validation_0-logloss:0.69128
# [67]	validation_0-logloss:0.69127
# [68]	validation_0-logloss:0.69129
# [69]	validation_0-logloss:0.69130
# [70]	validation_0-logloss:0.69136
# [71]	validation_0-logloss:0.69137
# [72]	validation_0-logloss:0.69136
# [73]	validation_0-logloss:0.69139
# [74]	validation_0-logloss:0.69141
# [0]	validation_0-logloss:0.69312
# [1]	validation_0-logloss:0.69309
# [2]	validation_0-logloss:0.69304
# [3]	validation_0-logloss:0.69301
# [4]	validation_0-logloss:0.69299
# [5]	validation_0-logloss:0.69299
# [6]	validation_0-logloss:0.69298
# [7]	validation_0-logloss:0.69299
# [8]	validation_0-logloss:0.69297
# [9]	validation_0-logloss:0.69299
# [10]	validation_0-logloss:0.69297
# [11]	validation_0-logloss:0.69303
# [12]	validation_0-logloss:0.69305
# [13]	validation_0-logloss:0.69310
# [14]	validation_0-logloss:0.69317
# [15]	validation_0-logloss:0.69312
# [16]	validation_0-logloss:0.69321
# [17]	validation_0-logloss:0.69328
# [18]	validation_0-logloss:0.69325
# [19]	validation_0-logloss:0.69333
# [20]	validation_0-logloss:0.69336
# [21]	validation_0-logloss:0.69335
# [22]	validation_0-logloss:0.69341
# [23]	validation_0-logloss:0.69342
# [24]	validation_0-logloss:0.69343
# Train Scores: 0.606 +/- 0.015
# Test Scores: 0.511 +/- 0.017

# %%
# Get the feature importances
importances = model.feature_importances_

# Create a series with feature names and importances
feat_imp = pd.Series(importances, index = features).sort_values()

# Plot 10 most important features
feat_imp.tail(20).plot(kind = "barh")
plt.xlabel("Gini Importance")
plt.ylabel("Feature")
plt.title("Feature Importance");


def make_cnf_matrix(threshold):
    
    y_pred_proba = model.predict_proba(X_test)[:,-1]
    y_pred = y_pred_proba > threshold
    conf_matrix = confusion_matrix(y_test,y_pred)
    tn,fp,fn,tp = conf_matrix.ravel()

    ConfusionMatrixDisplay.from_predictions(y_test,y_pred, colorbar = False)     

thresh_widget = widgets.FloatSlider(min=0,max=1,value=0.5,step=0.05)
interact(make_cnf_matrix, threshold=thresh_widget);
# Out:
# interactive(children=(FloatSlider(value=0.5, description='threshold', max=1.0, step=0.05), Output()), _dom_cla…

# %%
data = pre_process()
data = add_indicators(data)
data = add_signals(data)
data = backtest(data[90000:])
df = model_trade(data,model,features)
# Out:
# interactive(children=(FloatSlider(value=0.5, description='threshold', max=1.0, step=0.05), Output()), _dom_cla…
